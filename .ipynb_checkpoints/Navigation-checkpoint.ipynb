# %% [markdown]
# # Setting Up - Install Packages in the Workspace
# Before you move on to the project instruction, follow the cells below to ensure you have the necessary packages installed.
# The cells below will also educate you on installing newer pinned packages, should you need them in the future.

# %%
# Step 1. Update the PATH env var. 
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/home/student/.local/bin"
os.environ['PATH'] = f"{os.environ['PATH']}:/opt/conda/lib/python3.10/site-packages"
os.environ['PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION'] = 'python'

# %%
# Check the version of any specific package
# !python -m pip freeze | grep numpy
# Out:
# numpy @ file:///work/mkl/numpy_and_numpy_base_1682953417311/work

# %% [markdown]
# # Navigation
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment and Import
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install .

# %%
# Restart the Kernel. 
# If you skip this step, your notebook may not be able to import the packages well.

# %%
from agent import Agent

# %% [markdown]
# ### 2. Create and Train the Agent
#
# Create the agent with whatever hyperparameters you want to traing with and then train the agent with the `train_dqn()` method.

# %%
agent = Agent(soft_update_tau=1.0)
# Out:
# Found path: /data/Banana_Linux_NoVis/Banana.x86_64
# Mono path[0] = '/data/Banana_Linux_NoVis/Banana_Data/Managed'
# Mono config path = '/data/Banana_Linux_NoVis/Banana_Data/MonoBleedingEdge/etc'
# Preloaded 'libgrpc_csharp_ext.x64.so'
# Unable to preload the following plugins:
# 	libgrpc_csharp_ext.x86.so
# PlayerPrefs - Creating folder: /home/student/.config/unity3d/Unity Technologies
# PlayerPrefs - Creating folder: /home/student/.config/unity3d/Unity Technologies/Unity Environment
# Logging to /home/student/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
agent.train_dqn("solution_tau_1e0")
# Out:
# Episode 01651 | Epsilon: 0.010	Length: 300	Score: 14.00	Average Score: 13.04	Percent change: 4.3E-022
#
# Environment solved in 1651 episodes!	Average Score: 13.04

# %% [markdown]
# ### 3. Training Report

# %%
import agent as agent_module
from ast import literal_eval

import matplotlib.pyplot as plt

# %%
score = literal_eval(agent_module.DB_CUR.execute("SELECT scores FROM training_results WHERE tau IS 1.0").fetchone()[0])
moving_average = literal_eval(agent_module.DB_CUR.execute("SELECT moving_averages FROM training_results WHERE tau IS 1.0").fetchone()[0])
episode = [_ for _ in range(1, len(score) + 1)]

# %%
plt.plot(episode, score, label="Score")
plt.plot(episode[99::], moving_average, label="Moving Average")
plt.title("Training Score vs Episode Count")
plt.xlabel("Episode")
plt.ylabel("Score")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### 4. Exit

# %%
agent.close()
